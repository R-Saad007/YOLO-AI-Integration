# %% [markdown]
# # YOLOv8n (Nano) Model Training and Inferencing(Testing)

# %%
# Installing Ultralytics
# !pip install Ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Mouting google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/78.2 GB disk)

# %%
# Training on yolov8n (nano) model on GPU
# Saving results to folder yolov8n_results
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/yolov8/data.yaml epochs=10 imgsz=640 batch=8 project=/content/drive/MyDrive/yolov8/training_results name=yolov8n_results
# Out:
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Running inference (testing)
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8/training_results/yolov8n_results/weights/best.pt conf=0.55 source=/content/drive/MyDrive/yolov8/test/images
# Out:
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3013253 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/151 /content/drive/MyDrive/yolov8/test/images/Screenshot-from-2023-03-28-12-38-53_png.rf.80c4b40385207e6d11fe79f1fbc338fa.jpg: 640x352 1 back, 1 friends2, 1 group2, 1 page, 1 watch2, 65.6ms
# image 2/151 /content/drive/MyDrive/yolov8/test/images/Screenshot-from-2023-03-28-12-39-07_png.rf.a877bb87ba434822c34b4c7d0f7701c5.jpg: 640x352 7 profile5s, 9.3ms
# image 3/151 /content/drive/MyDrive/yolov8/test/images/Screenshot-from-2023-03-28-12-42-40_png.rf.cd4fa977b7213bd12f46045b1ee439af.jpg: 640x352 1 back, 6.9ms
# image 4/151 /content/drive/MyDrive/yolov8/test/images/Screenshot-from-2023-03-28-12-43-52_png.rf.3cb19357051de97031a39755c9a93966.jpg: 640x352 1 back, 1 friends2, 1 group2, 1 page, 1 watch2, 6.2ms
# ...

# %%
# Copying files from the runtime directory to the output directory on my drive
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/yolov8/yolov8n_outputs

# %% [markdown]
# # YOLOv8s (Small) Model Training and Inferencing(Testing)

# %%
# Training on yolov8s (small) model on GPU
# Saving results to folder yolov8s_results
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/yolov8/data.yaml epochs=10 imgsz=640 batch=8 project=/content/drive/MyDrive/yolov8/training_results name=yolov8s_results
# Out:
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Running inference (testing)
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8/training_results/yolov8s_results/weights/best.pt conf=0.55 source=/content/drive/MyDrive/yolov8/test/images
# Out:
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11140677 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/151 /content/drive/MyDrive/yolov8/test/images/Screenshot-from-2023-03-28-12-38-53_png.rf.80c4b40385207e6d11fe79f1fbc338fa.jpg: 640x352 1 back, 1 friends2, 1 group2, 1 page, 1 watch2, 71.9ms
# image 2/151 /content/drive/MyDrive/yolov8/test/images/Screenshot-from-2023-03-28-12-39-07_png.rf.a877bb87ba434822c34b4c7d0f7701c5.jpg: 640x352 7 profile5s, 10.8ms
# image 3/151 /content/drive/MyDrive/yolov8/test/images/Screenshot-from-2023-03-28-12-42-40_png.rf.cd4fa977b7213bd12f46045b1ee439af.jpg: 640x352 1 back, 1 search1, 10.6ms
# image 4/151 /content/drive/MyDrive/yolov8/test/images/Screenshot-from-2023-03-28-12-43-52_png.rf.3cb19357051de97031a39755c9a93966.jpg: 640x352 1 back, 1 friends2, 1 group2, 1 page, 1 watch2, 10.7ms
# ...

# %%
# Copying files from the runtime directory to the output directory on my drive
# !cp -r /content/runs/detect/predict4 /content/drive/MyDrive/yolov8/yolov8s_outputs

# %% [markdown]
# # YOLOv8m (Medium) Model Training and Inferencing(Testing)

# %%
# Training on yolov8m (medium) model on GPU
# Saving results to folder yolov8m_results
# !yolo task=detect mode=train model=yolov8m.pt data=/content/drive/MyDrive/yolov8/data.yaml epochs=10 imgsz=640 batch=8 project=/content/drive/MyDrive/yolov8/training_results name=yolov8m_results

# %%
# Running inference (testing)
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8/training_results/yolov8m_results/weights/best.pt conf=0.55 source=/content/drive/MyDrive/yolov8/test/images

# %%
# Copying files from the runtime directory to the output directory on my drive
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/yolov8/yolov8m_outputs
